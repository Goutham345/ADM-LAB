# %% [markdown]
# <a href="https://colab.research.google.com/github/Goutham345/ADM-LAB/blob/main/lab-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Load dataset (replace with your file path or URL)
url = '/content/titanic_clean.csv'
data = pd.read_csv(url)
print(data)
# Generate statistical summary of the dataset
# Out:
#       Unnamed: 0  pclass  survived  \
# 0              1     1.0       1.0
# 1              2     1.0       1.0
# 2              3     1.0       0.0
# 3              4     1.0       0.0
# 4              5     1.0       0.0
# ...          ...     ...       ...
# 1305        1306     3.0       0.0
# 1306        1307     3.0       0.0
# 1307        1308     3.0       0.0
# 1308        1309     3.0       0.0
# 1309        1310     NaN       NaN
#
#                                                  name     sex        age  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.000000
# 1                      Allison, Master. Hudson Trevor    male   0.916700
# 2                        Allison, Miss. Helen Loraine  female   2.000000
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.000000
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.000000
# ...                                               ...     ...        ...
# ...

# %%
summary = data.describe()
# Display the summary
print(summary)
# Out:
#         Unnamed: 0       pclass     survived          age        sibsp  \
# count  1310.000000  1309.000000  1309.000000  1310.000000  1309.000000
# mean    655.500000     2.294882     0.381971    29.881135     0.498854
# std     378.308736     0.837836     0.486055    12.878277     1.041658
# min       1.000000     1.000000     0.000000     0.166700     0.000000
# 25%     328.250000     2.000000     0.000000    22.000000     0.000000
# 50%     655.500000     3.000000     0.000000    29.881135     0.000000
# 75%     982.750000     3.000000     1.000000    35.000000     1.000000
# max    1310.000000     3.000000     1.000000    80.000000     8.000000
#
#              parch         fare        body  has_cabin_number
# count  1309.000000  1308.000000  121.000000       1310.000000
# mean      0.385027    33.295479  160.809917          0.225191
# std       0.865560    51.758668   97.696922          0.417867
# min       0.000000     0.000000    1.000000          0.000000
# ...

# %%
print(data.describe(include=['object']))
# Out:
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1310  486
# unique                  1307     2       929          186        3   27
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      917   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset (replace with your file path or URL)
url = '/content/titanic_clean.csv'
data = pd.read_csv(url)

# Check if 'Age' column exists, if not, check for possible variations
if 'Age' not in data.columns:
    # Possible alternatives for 'Age'
    alternatives = ['age', 'Age ', 'AGE']
    for alt in alternatives:
        if alt in data.columns:
            print(f"Found column '{alt}' instead of 'Age'. Replacing...")
            data.rename(columns={alt: 'Age'}, inplace=True)
            break
    else:
        print("Column 'Age' or its variations not found in the dataset.")
        # You may need to further investigate your data or data loading process

# Plot histogram for 'Age' column
plt.hist(data['Age'].dropna(), bins=20, edgecolor='black', color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# Found column 'age' instead of 'Age'. Replacing...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset (replace with your file path or URL)
url = '/content/titanic_clean.csv'
data = pd.read_csv(url)

# Check if 'Pclass' column exists, if not, check for possible variations
if 'Pclass' not in data.columns:
    # Possible alternatives for 'Pclass'
    alternatives = ['pclass', 'PClass ', 'passenger_class']  # Add potential variations
    for alt in alternatives:
        if alt in data.columns:
            print(f"Found column '{alt}' instead of 'Pclass'. Replacing...")
            data.rename(columns={alt: 'Pclass'}, inplace=True)
            break
    else:
        print("Column 'Pclass' or its variations not found in the dataset.")
        # You may need to further investigate your data or data loading process

# Bar chart for 'Pclass' (Passenger class)
plt.figure(figsize=(6, 4))
data['Pclass'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('Passenger Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# ... (rest of your plotting code)
# Out:
# Found column 'pclass' instead of 'Pclass'. Replacing...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset (replace with your file path or URL)
url = '/content/titanic_clean.csv'
data = pd.read_csv(url)

# Check if 'Age' column exists, if not, check for possible variations
if 'Age' not in data.columns:
    # Possible alternatives for 'Age'
    alternatives = ['age', 'Age ', 'AGE']
    for alt in alternatives:
        if alt in data.columns:
            print(f"Found column '{alt}' instead of 'Age'. Replacing...")
            data.rename(columns={alt: 'Age'}, inplace=True)
            break
    else:
        print("Column 'Age' or its variations not found in the dataset.")
        # You may need to further investigate your data or data loading process

# Box plot for 'Age' to visualize outliers and distribution
plt.figure(figsize=(6, 4))
# Access the 'Age' column (or the renamed column if an alternative was found)
plt.boxplot(data['Age'].dropna(), patch_artist=True,
            boxprops=dict(facecolor='lightgreen'))
plt.title('Box Plot of Age')
plt.ylabel('Age')
plt.show()
# Out:
# Found column 'age' instead of 'Age'. Replacing...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset (replace with your file path or URL)
url = '/content/titanic_clean.csv'
data = pd.read_csv(url)

# Print the actual column names in your DataFrame
print(data.columns)

# Adjust the column names to match the actual names in your DataFrame
# Example: If your DataFrame has 'age' instead of 'Age', use 'age' below
sns.pairplot(data[['age', 'fare', 'sibsp', 'parch']].dropna())  # Replace with correct column names
plt.show()
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest', 'has_cabin_number'],
#       dtype='object')

# %%
# Correlation heatmap
# Original line: correlation_matrix = data[['Age', 'Fare', 'SibSp', 'Parch']].corr()

# Check the actual column names in your DataFrame
print(data.columns)

# Adjust the column names in the following line to match the actual names in your DataFrame
correlation_matrix = data[['age', 'pclass', 'sibsp', 'parch']].corr()  # Replace with correct column names

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap')
plt.show()
#Count Plot
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest', 'has_cabin_number'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load dataset (replace with your file path or URL)
url = '/content/titanic_clean.csv'
data = pd.read_csv(url)

# Check if 'Survived' column exists, if not, check for possible variations
if 'Survived' not in data.columns:
    # Possible alternatives for 'Survived'
    alternatives = ['survived', 'SURVIVED', 'PassengerSurvived']  # Add potential variations
    for alt in alternatives:
        if alt in data.columns:
            print(f"Found column '{alt}' instead of 'Survived'. Replacing...")
            data.rename(columns={alt: 'Survived'}, inplace=True)
            break
    else:
        print("Column 'Survived' or its variations not found in the dataset.")
        # You may need to further investigate your data or data loading process


# Now you can create the count plot
sns.countplot(x='Survived', data=data, palette='Set2')
plt.title('Survival Count')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()
# Out:
# Found column 'survived' instead of 'Survived'. Replacing...
# <ipython-input-66-a42b1952f390>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=data, palette='Set2')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load dataset (replace with your file path or URL)
url = '/content/titanic_clean.csv'
data = pd.read_csv(url)

# Check if 'Age' column exists, if not, check for possible variations
if 'Age' not in data.columns:
    # Possible alternatives for 'Age'
    alternatives = ['age', 'Age ', 'AGE']
    for alt in alternatives:
        if alt in data.columns:
            print(f"Found column '{alt}' instead of 'Age'. Replacing...")
            data.rename(columns={alt: 'Age'}, inplace=True)
            break
    else:
        print("Column 'Age' or its variations not found in the dataset.")
        # You may need to further investigate your data or data loading process

# Violin plot for 'Age' across 'Pclass'
# Ensure 'pclass' is used for the x-axis as 'Pclass' may not exist
sns.violinplot(x='pclass', y='Age', data=data, palette='muted')
plt.title('Age Distribution by Passenger Class')
plt.show()
# Out:
# Found column 'age' instead of 'Age'. Replacing...
# <ipython-input-67-7e02aef1012a>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='pclass', y='Age', data=data, palette='muted')
